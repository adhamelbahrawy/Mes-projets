# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("synthetic.csv")
cols = df.columns.values.tolist()
# Out:
# Attr_A
# Attr_B
# Attr_C
# Attr_D
# Attr_E
# Attr_F
# Attr_G
# Attr_H
# Attr_I
# Attr_J
# Attr_K
# Attr_L
# Attr_M
# Attr_N

# %%
# df.sort_values(by=['Class']).tail(10)
ech = df.sample(100)
ech
# Out:
#          Attr_A     Attr_B       Attr_C      Attr_D      Attr_E       Attr_F  \
# 992   11.455762  10.958984   940.597908   88.605428  130.927113   884.937847
# 239   13.122179  10.460414   996.028314  114.983115   91.103368  1103.731143
# 2088   8.959012  11.290937  1099.665175   97.955974  118.433728  1104.300128
# 1655  10.508696  10.683752   776.924931   94.472193  110.571166   798.801937
# 2138  10.184168   9.620717   859.114964  106.739444   91.842978   503.421855
# ...         ...        ...          ...         ...         ...          ...
# 1613  10.005461   9.680270   950.320691   94.241598  118.991185  1159.627461
# 1712   9.829278  11.719817   794.605681   89.223810  104.986437   931.060419
# 230    9.187521   8.215358   884.631452   94.058764  127.743671   944.840536
# 22    11.024802   9.796339   720.091322   97.537256   97.514606   993.866632
# 2142  11.985958   8.823458   662.106037   96.903112   98.699048   955.080797
#
# ...

# %%
import seaborn as sns
sns.pairplot(ech , hue="Class")
